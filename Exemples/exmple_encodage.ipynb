# %% [markdown]
# Dans le cas ou les données sont textuelles il faut les changer en données numériques  pour le modèle

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing as LabelEncoder
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
import pandas as pd

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# Replace une valeur manquante

# %% [markdown]
# ![{B88B47A2-DEAC-4733-8BF9-A46005C2894B}.png](attachment:{B88B47A2-DEAC-4733-8BF9-A46005C2894B}.png)

# %%
x = np.array([[10,3],[0,4],[5,3],[np.nan,3]])

imputer = SimpleImputer(missing_values=np.nan,strategy='mean')

imputer.fit_transform(x)
# Out:
# array([[10.,  3.],
#        [ 0.,  4.],
#        [ 5.,  3.],
#        [ 5.,  3.]])

# %% [markdown]
# Si le tableau a plusieurs colonnes : OrdinalEncoder()/OneHotEncoder

# %%
x = np.array(["tortue", "poulet", "tortue", "poulet", "koala"])

encoder = LabelEncoder()

encoded_y = encoder.fit_transform(x)

encoded_y
# Out:
# array([2, 1, 2, 1, 0], dtype=int64)

# %%
decoded_y = encoder.inverse_transform(encoded_y)
decoded_y
# Out:
# array(['tortue', 'poulet', 'tortue', 'poulet', 'koala'], dtype='<U6')

# %%
encoder.inverse_transform(np.array([0,0,2,2]))
# Out:
# array(['koala', 'koala', 'tortue', 'tortue'], dtype='<U6')

# %%
x2 = np.array([["tortue", "écailles"],["poulet", "plumes"],["poulet", "plumes"]])
encoder = OrdinalEncoder()
encoded_data = encoder.fit_transform(x2)
encoded_data
# Out:
# array([[1., 1.],
#        [0., 0.],
#        [0., 0.]])

# %%
x2 = np.array([["tortue", "écailles"],["poulet", "plumes"],["poulet", "plumes"]])
encoder = OneHotEncoder()
encoded_data = encoder.fit_transform(x2)
encoded_data
# Out:
# <3x4 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Normalisation :

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
x = np.array ([[70],[80],[120]])

scaler = MinMaxScaler()
scaler.fit_transform(x)
# Out:
# array([[0. ],
#        [0.2],
#        [1. ]])

# %%
from sklearn.preprocessing import  StandardScaler, RobustScaler
from sklearn.datasets import load_iris

# %%
x = np.array ([[70],[80],[120]])

scaler = StandardScaler()
scaler.fit_transform(x)
# Out:
# array([[-0.9258201 ],
#        [-0.46291005],
#        [ 1.38873015]])

# %%
x_robust= RobustScaler().fit_transform(x)
x_robust
# Out:
# array([[-0.4],
#        [ 0. ],
#        [ 1.6]])

# %% [markdown]
# Training

# %%
pd.read
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 pd.read.table
#
# AttributeError: module 'pandas' has no attribute 'read'
